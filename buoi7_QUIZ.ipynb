# %% [markdown]
# # 📊 KHÓA HỌC EXCEL SALES DASHBOARD — BUỔI 7
# ## 🏆 QUIZ TỔNG KẾT CUỐI KHÓA
#
# ---
#
# **Điều hướng nhanh:**
# [Buổi 1 — Giới thiệu](buoi1_INTRODUCTION.ipynb) |
# [Buổi 2 — Chuẩn bị dữ liệu](buoi2_DATA_PREPARATION.ipynb) |
# [Buổi 3 — PivotTables](buoi3_PIVOTTABLES.ipynb) |
# [Buổi 4 — PivotCharts](buoi4_PIVOTCHARTS.ipynb) |
# [Buổi 5 — Slicers & KPI Cards](buoi5_SLICERS&KPI_CARDS.ipynb) |
# [Buổi 6 — Dashboard Layout](buoi6_DASHBOARD_LAYOUT&FORMATTING.ipynb) |
# 📍 **Buổi 7 — Quiz**
#
# ---
#
# ## 🎯 Mục tiêu buổi 7
#
# Kiểm tra và xác nhận toàn bộ kiến thức đã học qua 6 buổi — từ chuẩn bị dữ liệu đến hoàn thiện Dashboard chuyên nghiệp.
#
# ---
#
# ## 📋 Hướng dẫn làm bài
#
# | Mục | Chi tiết |
# |---|---|
# | **Tổng số câu** | 20 câu trắc nghiệm (A/B/C/D) |
# | **Phân bổ độ khó** | Câu 1–12: Cơ bản 🟢 — Câu 13–18: Vận dụng 🟡 — Câu 19–20: Suy luận 🔴 |
# | **Thang điểm** | Mỗi câu đúng = 0.5 điểm → Tổng tối đa **10 điểm** |
# | **Mức đạt** | ≥ 7 điểm (14/20 câu) |
# | **Cách làm** | Đọc kỹ từng câu, ghi đáp án ra giấy, sau đó đối chiếu với bảng đáp án ở cuối |
# | **Thời gian tham khảo** | 25–30 phút |
#
# > 💡 **Lưu ý:** Không xem đáp án trước khi làm xong toàn bộ 20 câu.
#
# ---
#
# ### Bảng phân bổ câu hỏi theo chủ đề
#
# | Chủ đề | Số câu | Câu số |
# |---|---|---|
# | Buổi 1 — Giới thiệu Dashboard | 1 | 1 |
# | Buổi 2 — Chuẩn bị dữ liệu & Excel Table | 4 | 2, 3, 4, 5 |
# | Buổi 3 — PivotTables | 5 | 6, 7, 8, 13, 14 |
# | Buổi 4 — PivotCharts | 3 | 9, 15, 16 |
# | Buổi 5 — Slicers & KPI Cards | 4 | 10, 11, 12, 17 |
# | Buổi 6 — Dashboard Layout & Formatting | 3 | 18, 19, 20 |

# %% [markdown]
# ---
#
# # PHẦN 1 — KIẾN THỨC CƠ BẢN 🟢
# ### (Câu 1–12 — mỗi câu 0.5 điểm)
#
# > Các câu này kiểm tra kiến thức nền tảng — hầu hết đều đã được học trực tiếp trong bài giảng.
#
# ---
#
# ### Câu 1 🟢
# **Excel Dashboard có ưu điểm gì so với báo cáo bảng số thông thường?**
#
# - A. Dashboard chạy nhanh hơn vì ít dữ liệu hơn
# - B. Dashboard tích hợp sẵn AI để dự báo xu hướng
# - C. Dashboard trực quan hóa dữ liệu bằng biểu đồ và KPI, giúp ra quyết định nhanh hơn
# - D. Dashboard chỉ dành cho doanh nghiệp lớn có bộ phận IT
#
# ---
#
# ### Câu 2 🟢
# **Để chuyển vùng dữ liệu thông thường thành Excel Table, ta dùng phím tắt nào?**
#
# - A. Ctrl + E
# - B. Ctrl + T (hoặc Ctrl + L)
# - C. Ctrl + Shift + T
# - D. Alt + T, sau đó Enter
#
# ---
#
# ### Câu 3 🟢
# **Công thức đúng để tính cột Profit từ dữ liệu SalesData là:**
#
# - A. `=Revenue + Cost`
# - B. `=Revenue * Cost`
# - C. `=Revenue - Cost`
# - D. `=IF(Revenue>Cost, Revenue, Cost)`
#
# ---
#
# ### Câu 4 🟢
# **Hàm nào được dùng để lấy năm (4 chữ số) từ cột Order_Date?**
#
# - A. `=DATE(Order_Date)`
# - B. `=DATEVALUE(Order_Date)`
# - C. `=MONTH(Order_Date)`
# - D. `=YEAR(Order_Date)`
#
# ---
#
# ### Câu 5 🟢
# **Trong dataset SalesData, tại sao cần đặt tên cho Excel Table là "SalesData" thay vì giữ tên mặc định "Table1"?**
#
# - A. Excel bắt buộc phải đặt tên trước khi tạo PivotTable
# - B. Tên có ý nghĩa giúp công thức GETPIVOTDATA và PivotTable dễ đọc, dễ quản lý hơn
# - C. Tên "Table1" gây lỗi khi có nhiều sheet
# - D. Không có lý do — chỉ là thói quen
#
# ---
#
# ### Câu 6 🟢
# **PivotTable có mấy vùng kéo thả chính trong PivotTable Fields pane?**
#
# - A. 2 vùng (Rows và Values)
# - B. 3 vùng (Rows, Columns, Values)
# - C. 4 vùng (Filters, Columns, Rows, Values)
# - D. 5 vùng (Filters, Columns, Rows, Values, Sort)
#
# ---
#
# ### Câu 7 🟢
# **Để làm mới (Refresh) tất cả PivotTables trong toàn bộ file Excel cùng lúc, ta dùng phím tắt nào?**
#
# - A. F5
# - B. Ctrl + R
# - C. Ctrl + Alt + F5
# - D. Alt + F9
#
# ---
#
# ### Câu 8 🟢
# **Loại chart nào phù hợp nhất để hiển thị xu hướng Doanh thu theo từng tháng trong năm?**
#
# - A. Pie Chart
# - B. Line Chart
# - C. Bar Chart (ngang)
# - D. Doughnut Chart
#
# ---
#
# ### Câu 9 🟢
# **Sau khi tạo PivotChart trên sheet PT_Monthly, để di chuyển chart sang sheet Dashboard, ta làm gì?**
#
# - A. Ctrl + X → click Dashboard → Ctrl + V
# - B. Tab **Chart Design** → **Move Chart** → chọn **Object in: Dashboard**
# - C. Right-click chart → **Cut** → mở sheet Dashboard → **Paste Special**
# - D. Không thể di chuyển chart giữa các sheet — phải tạo lại
#
# ---
#
# ### Câu 10 🟢
# **Report Connections trong Excel Slicer dùng để làm gì?**
#
# - A. Kết nối Excel với internet để cập nhật dữ liệu tự động
# - B. Liên kết một Slicer với nhiều PivotTable cùng lúc, để 1 lần click lọc tất cả charts
# - C. Kết nối 2 workbook Excel khác nhau với nhau
# - D. Tạo hyperlink từ Slicer sang sheet khác
#
# ---
#
# ### Câu 11 🟢
# **Trong custom number format, hai dấu phẩy ở cuối (,,) có tác dụng gì?**
#
# - A. Thêm dấu phẩy ngăn cách hàng nghìn
# - B. Chia giá trị cho 1,000 (nghìn)
# - C. Chia giá trị cho 1,000,000 (triệu) — thu gọn số lớn
# - D. Nhân giá trị cho 1,000,000
#
# ---
#
# ### Câu 12 🟢
# **Hàm nào dùng để đếm số lượng đơn hàng trong cột Order_ID (dạng text như "ORD-001")?**
#
# - A. `=COUNT(SalesData[Order_ID])`
# - B. `=SUM(SalesData[Order_ID])`
# - C. `=COUNTA(SalesData[Order_ID])`
# - D. `=COUNTBLANK(SalesData[Order_ID])`

# %% [markdown]
# ---
#
# # PHẦN 2 — VẬN DỤNG 🟡
# ### (Câu 13–18 — mỗi câu 0.5 điểm)
#
# > Các câu này yêu cầu hiểu sâu hơn — không chỉ nhớ thao tác mà còn biết tại sao.
#
# ---
#
# ### Câu 13 🟡
# **PivotTable PT_Segment trong khóa học phân tích điều gì?**
#
# - A. Doanh thu theo từng sản phẩm riêng lẻ trong từng Category
# - B. Lợi nhuận theo chương trình khuyến mãi (Promotion)
# - C. Doanh thu theo phân khúc khách hàng (Consumer / Corporate / Home Office) × Năm, kèm % tăng trưởng YoY
# - D. Số lượng đơn hàng theo từng Region
#
# ---
#
# ### Câu 14 🟡
# **Khi muốn xem PivotTable PT_Monthly hiển thị mức tăng/giảm doanh thu so với tháng trước (MoM%), ta cài đặt ở đâu?**
#
# - A. Value Field Settings → Summarize Values By → Average
# - B. Value Field Settings → Show Values As → **% Difference From** → Base field: Month → Base item: (previous)
# - C. Insert → Calculated Field → nhập công thức `=(Revenue_ThangNay - Revenue_ThangTruoc) / Revenue_ThangTruoc`
# - D. Right-click cột Revenue → Sort → Sort Largest to Smallest
#
# ---
#
# ### Câu 15 🟡
# **Khi nào nên dùng Combo Chart (biểu đồ kết hợp) thay vì một loại chart đơn thuần?**
#
# - A. Khi có quá nhiều categories (trên 20 mục)
# - B. Khi muốn so sánh 2 metrics có đơn vị khác nhau trên cùng 1 biểu đồ (ví dụ: Revenue theo cột và Profit Margin % theo đường)
# - C. Khi dataset có dưới 5 điểm dữ liệu
# - D. Khi muốn ẩn một phần dữ liệu khỏi người xem
#
# ---
#
# ### Câu 16 🟡
# **Trong công thức `=GETPIVOTDATA("Revenue", PT_Region!$A$3)`, phần `PT_Region!$A$3` có ý nghĩa gì?**
#
# - A. Chỉ lấy giá trị từ đúng ô A3 trong sheet PT_Region
# - B. Tham chiếu đến một ô bất kỳ bên trong PivotTable — dùng để Excel xác định PivotTable nào cần truy vấn
# - C. Giới hạn chỉ lấy dữ liệu từ hàng 3 trở xuống của PivotTable
# - D. Tham chiếu đến ô tiêu đề (header) của cột Revenue
#
# ---
#
# ### Câu 17 🟡
# **Tại sao trong Buổi 5, khi tạo KPI Card "Số đơn hàng", khóa học dùng `COUNTA` thay vì `COUNT`?**
#
# - A. COUNTA cho kết quả lớn hơn COUNT nên số đẹp hơn
# - B. COUNT chỉ đếm ô chứa số, còn COUNTA đếm tất cả ô không trống — Order_ID là dạng text nên phải dùng COUNTA
# - C. COUNT bị lỗi khi dùng với Excel Table
# - D. Không có sự khác biệt — cả hai đều cho kết quả như nhau với Order_ID
#
# ---
#
# ### Câu 18 🟡
# **Trong Dashboard Layout (Buổi 6), tại sao nên dùng "Merge Across" thay vì "Merge & Center" khi tạo tiêu đề cho các hàng trong KPI Card?**
#
# - A. Merge Across có thêm tùy chọn căn chỉnh màu sắc
# - B. Merge Across gộp các ô trong từng hàng riêng biệt (giữ lại cấu trúc nhiều hàng); còn Merge & Center gộp toàn bộ vùng chọn thành 1 ô duy nhất — làm mất các hàng bên trong
# - C. Merge & Center không thể áp dụng cho vùng chứa nhiều hàng
# - D. Merge Across giúp Excel tự động điều chỉnh kích thước font chữ

# %% [markdown]
# ---
#
# # PHẦN 3 — SUY LUẬN & PHÂN TÍCH 🔴
# ### (Câu 19–20 — mỗi câu 0.5 điểm)
#
# > Các câu này không có câu trả lời trong bài giảng — yêu cầu áp dụng kiến thức vào tình huống thực tế.
#
# ---
#
# ### Câu 19 🔴
# **Tình huống thực tế:**
#
# Anh Minh — Giám đốc Kinh doanh — yêu cầu bạn gửi báo cáo Dashboard tháng này qua email cho toàn bộ Ban Giám Đốc. Các thành viên BGĐ không cần tương tác (không cần dùng Slicer lọc), chỉ cần xem Dashboard đúng như bạn đang thấy.
#
# **Nên lưu và gửi file dưới định dạng nào?**
#
# - A. `.xlsx` — để người nhận thấy đầy đủ Slicers và Charts
# - B. `.csv` — nhỏ gọn, dễ gửi qua email
# - C. `.pdf` — giữ nguyên layout, không thể chỉnh sửa vô ý, mở được trên mọi thiết bị
# - D. `.pptx` — chuyển sang PowerPoint cho dễ trình chiếu trong họp
#
# ---
#
# ### Câu 20 🔴
# **Tình huống thực tế — Xử lý lỗi:**
#
# Bạn vừa hoàn thành Dashboard với 3 Slicers (Region, Category, Quarter). Khi test, bạn click Slicer Region chọn "Miền Bắc" — nhưng chỉ có 2 trong 4 Charts thay đổi dữ liệu, 2 Charts còn lại vẫn hiển thị toàn bộ dữ liệu chưa lọc.
#
# **Nguyên nhân khả năng nhất là gì? Và cách khắc phục?**
#
# - A. Slicer bị lỗi — cần xóa đi và tạo lại từ đầu
# - B. 2 Charts không thay đổi đang được kết nối với PivotTable chưa được thiết lập **Report Connections** với Slicer Region — cần right-click Slicer → Report Connections → tick thêm các PivotTable bị thiếu
# - C. PivotChart không thể kết nối với Slicer — chỉ PivotTable mới kết nối được, phải dùng cách khác
# - D. Cần nhấn **Ctrl + Alt + F5** (Refresh All) sau mỗi lần click Slicer thì Charts mới cập nhật
#
# ---
# ---
#
# # 📋 BẢNG ĐÁP ÁN CHÍNH THỨC
#
# > ⚠️ Chỉ mở phần này sau khi đã làm xong toàn bộ 20 câu.
#
# ---
#
# | Câu | Đáp án | Giải thích nhanh |
# |---|---|---|
# | **1** | **C** | Dashboard = trực quan hóa → ra quyết định nhanh hơn |
# | **2** | **B** | Ctrl+T (hoặc Ctrl+L) tạo Excel Table |
# | **3** | **C** | Profit = Revenue − Cost |
# | **4** | **D** | `=YEAR(Order_Date)` lấy năm dạng số |
# | **5** | **B** | Tên có nghĩa giúp công thức rõ ràng và dễ quản lý |
# | **6** | **C** | 4 vùng: Filters, Columns, Rows, Values |
# | **7** | **C** | Ctrl+Alt+F5 = Refresh All |
# | **8** | **B** | Line Chart tốt nhất cho xu hướng theo thời gian |
# | **9** | **B** | Chart Design → Move Chart → Object in: Dashboard |
# | **10** | **B** | Report Connections = liên kết 1 Slicer với nhiều PivotTable |
# | **11** | **C** | `,,` ở cuối format = chia cho 1,000,000 |
# | **12** | **C** | COUNTA đếm ô không trống (text); COUNT chỉ đếm số |
# | **13** | **C** | PT_Segment: Segment × Year + YoY% |
# | **14** | **B** | Show Values As → % Difference From → Month → (previous) |
# | **15** | **B** | Combo Chart dùng khi 2 metrics khác đơn vị |
# | **16** | **B** | `PT_Region!$A$3` xác định PivotTable cần truy vấn |
# | **17** | **B** | COUNTA đếm text; COUNT không đếm được text như Order_ID |
# | **18** | **B** | Merge Across giữ cấu trúc nhiều hàng; Merge & Center gộp thành 1 ô |
# | **19** | **C** | PDF: giữ nguyên layout, mở được mọi nơi, không chỉnh sửa |
# | **20** | **B** | Thiếu Report Connections → right-click Slicer → tick PivotTable bị thiếu |
#
# ---
#
# ## 🎯 THANG ĐIỂM & ĐÁNH GIÁ
#
# | Điểm | Số câu đúng | Đánh giá |
# |---|---|---|
# | 9.5 – 10 | 19–20 câu | 🏆 **Xuất sắc** — Sẵn sàng xây Dashboard thực tế độc lập |
# | 8.0 – 9.0 | 16–18 câu | ⭐ **Giỏi** — Nắm vững kiến thức, cần thêm thực hành |
# | 7.0 – 7.5 | 14–15 câu | ✅ **Đạt** — Đủ nền tảng, ôn lại các phần còn yếu |
# | 5.0 – 6.5 | 10–13 câu | 📖 **Cần ôn thêm** — Xem lại buổi có nhiều câu sai |
# | < 5.0 | < 10 câu | 🔄 **Cần học lại** — Nên xem lại từ Buổi 2 |
#
# ---
#
# ## 📌 GỢI Ý ÔN TẬP THEO CHỦ ĐỀ
#
# Nếu sai nhiều câu ở nhóm nào, xem lại buổi tương ứng:
#
# | Câu sai | Buổi cần ôn |
# |---|---|
# | Câu 1 | [Buổi 1 — Giới thiệu](buoi1_INTRODUCTION.ipynb) |
# | Câu 2, 3, 4, 5 | [Buổi 2 — Chuẩn bị dữ liệu](buoi2_DATA_PREPARATION.ipynb) |
# | Câu 6, 7, 13, 14 | [Buổi 3 — PivotTables](buoi3_PIVOTTABLES.ipynb) |
# | Câu 8, 9, 15, 16 | [Buổi 4 — PivotCharts](buoi4_PIVOTCHARTS.ipynb) |
# | Câu 10, 11, 12, 17 | [Buổi 5 — Slicers & KPI Cards](buoi5_SLICERS&KPI_CARDS.ipynb) |
# | Câu 18, 19, 20 | [Buổi 6 — Dashboard Layout](buoi6_DASHBOARD_LAYOUT&FORMATTING.ipynb) |
#
# ---
#
# ## 🎉 CHÚC MỪNG HOÀN THÀNH KHÓA HỌC!
#
# Bạn đã hoàn thành **7 buổi học Excel Sales Dashboard** — từ dữ liệu thô đến Dashboard chuyên nghiệp!
#
# **Những gì bạn đã làm được:**
# - Chuẩn bị và làm sạch dữ liệu, thêm 8 cột tính toán tự động
# - Xây dựng 6 PivotTable phân tích dữ liệu theo nhiều chiều
# - Tạo 6 loại biểu đồ chuyên nghiệp (Line, Bar, Doughnut, Column, Combo, Stacked)
# - Kết nối 3 Slicers tương tác với toàn bộ Dashboard
# - Thiết kế 4 KPI Cards với dữ liệu động theo GETPIVOTDATA
# - Hoàn thiện layout, màu sắc, typography và Conditional Formatting
#
# **Bước tiếp theo:** Áp dụng kiến thức này vào dữ liệu kinh doanh thực tế của bạn!
#
# ---
#
# *📅 Buổi 7 / 7 — KẾT THÚC KHÓA HỌC | 📊 Excel Sales Dashboard*
